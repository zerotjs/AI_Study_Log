# %%
#1 변수 기본예제
name = 'Alice'
age = 25
address = '''우편번호 12345
서울시 영등포구 여의도동
서울빌딩 501호'''
boyfriend = None
height = 168.5

print(name)
print(age)
print(address)
print(boyfriend)
print(height)

# %% [markdown]
# # 기본 자료형
#
# - 종류 : **int, float, bool, str**
#
# 1. 정수(int)
# 10진수, 2진수, 8진수, 16진수로 표현 가능
# 10진수 : 0~9로 시작하는 숫자
#     예시 : n = 95

# %%
#2 기본 자료형
